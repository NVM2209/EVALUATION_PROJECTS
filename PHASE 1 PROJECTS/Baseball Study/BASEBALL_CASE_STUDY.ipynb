# %% [markdown]
# ##  EVALUATION PROJECT  |  PHASE -1 | PROJECT - 1
#
# # BASEBALL CASE STUDY  |
#
# FlipRoboTechnology   | Batch - DS2301   |   Submitted By :- Neha Vibhor Mittal

# %% [markdown]
# ### DATASET INFORMATION-
#
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# #### This dataset is available on :
#
#    - 'https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv'.

# %% [markdown]
# ### PROBLEM IDENTIFICATION -
#
# - To predicts the number of wins for a Major League Baseball team in the 2015 season based on several different indicators of success.

# %% [markdown]
# ### TARGET VARIABLE :
#
#    - Number of predicted wins (W)

# %% [markdown]
# ### LABELS / ATTRIBUTE INFORMATION :-
#
# There are 16 different features that will be used as the inputs to the machine learning model and the output will be a value that represents the number of wins.
#
# ####   - Input features-  Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts,Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors.
#
# #### - Output Feature- Number of predicted wins (W)
#
#
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# ### TOOLS USED :-
# The following tools are going to be used for data analysis-
#
# - Pandas
# - Numpy
# - Matplotlib
# - Seaborn
# - scipy.stats
# - Scikit-learn

# %% [markdown]
# ### CONTENT
# #### (Steps to perform)-
#
# - 1) Importing necessary libraries
# - 2)  Load the dataset
# - 3) Data preprocessing(EDA)- Observe the type of data, Columns in the dataset if not present then replacing it, shape of the dataset(rows and columns),Information of the data .
# - 4) statistical summary of data.
# - 5) Check for missing values and correlation matrix
# - 6) Correlation of columns with target variable.
# - 7) Data visualization
# - Univariate analysis - Using histogram plot
# - Bivariate analysis(with target column) - Using reg plot
# 8) Distribution of data in columns - Skewess
# - 9) Check for outliers in data
# - 10) Remove skewness and outliers from data.
# - 11) Check Multicolinearity of variables and dropped two columns with high variance of inflation.
# - 12) Apply scalling techniques
# - 13 )Model building
# - 14) Cross validation
# - 15) Hyperparameter tunning
# - 16) Saving the best fit model .

# %% [markdown]
# ### IMPORTING NECESSARY LIBRARIES-

# %%
#Importing libraries :

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### LOAD THE DATASET -

# %%
# Loading the dataset:

baseball=pd.read_csv('C:/Users/nehas/NehaProject/EVALUATION PROJECTS/PHASE 1 PROJECTS/Baseball Study/baseball.csv')
baseball
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# #### -Target in Dataset(Dependent Variable)- 'Wins'

# %% [markdown]
# ### Exploratory Data Analysis(EDA)

# %%
# Replacing the abbrevations with Complete word and to enchance the interpretation.

baseball.columns = 'Wins','Runs','At_Bats','Hits','Doubles','Triples','Homeruns','Walks','Strikeouts','Stolen_Bases','Runs_Allowed','Earned_Runs','EarnedRun_Average(ERA)','Complete_game', 'Shutout','Save','Errors'

# %%
baseball.head()
# Out:
#    Wins  Runs  At_Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42       139    383         973
# 1    83   696     5467  1349      277       44       156    439        1264
# 2    81   669     5439  1395      303       29       141    533        1157
# 3    76   622     5533  1381      260       27       136    404        1231
# 4    74   689     5605  1515      289       49       151    455        1259
#
#    Stolen_Bases  Runs_Allowed  Earned_Runs  EarnedRun_Average(ERA)  \
# 0           104           641          601                    3.73
# 1            70           700          653                    4.07
# 2            86           640          584                    3.67
# 3            68           701          643                    3.98
# 4            83           803          746                    4.64
#
#    Complete_game  Shutout  Save  Errors
# 0              2        8    56      88
# ...

# %%
# Checking the shape of the dataset-

baseball.shape
# Out:
# (30, 17)

# %% [markdown]
# - There are 30 rows and 17 columns in our data.

# %%
#Checkin the data types of all teh features-

baseball.dtypes
# Out:
# Wins                        int64
# Runs                        int64
# At_Bats                     int64
# Hits                        int64
# Doubles                     int64
# Triples                     int64
# Homeruns                    int64
# Walks                       int64
# Strikeouts                  int64
# Stolen_Bases                int64
# Runs_Allowed                int64
# Earned_Runs                 int64
# EarnedRun_Average(ERA)    float64
# Complete_game               int64
# Shutout                     int64
# Save                        int64
# Errors                      int64
# dtype: object

# %%
# Checking the info of the features in the dataset-

baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Wins                    30 non-null     int64
#  1   Runs                    30 non-null     int64
#  2   At_Bats                 30 non-null     int64
#  3   Hits                    30 non-null     int64
#  4   Doubles                 30 non-null     int64
#  5   Triples                 30 non-null     int64
#  6   Homeruns                30 non-null     int64
#  7   Walks                   30 non-null     int64
#  8   Strikeouts              30 non-null     int64
#  9   Stolen_Bases            30 non-null     int64
#  10  Runs_Allowed            30 non-null     int64
#  11  Earned_Runs             30 non-null     int64
#  12  EarnedRun_Average(ERA)  30 non-null     float64
#  13  Complete_game           30 non-null     int64
# ...

# %% [markdown]
# #### KEY OBSERVATIONS-
#
# - There are 30 entries in our dataset with 17 attributes .
# - All of the features in this dataset are numeric except 'EarnedRun_Average(ERA)' which is float6 datatype.
# - The second column give us an idea about how big the dataset and how many non-null values are there for each field.
# - Now that we have got a glimpse of the dataset, we know that it doesn't have any null values and all the attributes are numerical including our target variable ' Wins '.
# - The total memory usage is 4.1 KB

# %%
 # Checking for missing values in the dataset-
    
plt.figure(figsize=[9,9])
sns.heatmap(baseball.isnull())

print(baseball.isna().sum())
# Out:
# Wins                      0
# Runs                      0
# At_Bats                   0
# Hits                      0
# Doubles                   0
# Triples                   0
# Homeruns                  0
# Walks                     0
# Strikeouts                0
# Stolen_Bases              0
# Runs_Allowed              0
# Earned_Runs               0
# EarnedRun_Average(ERA)    0
# Complete_game             0
# Shutout                   0
# Save                      0
# Errors                    0
# dtype: int64

# %%
# Checking the duplicate values if any.

baseball.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There is no duplicate values in this dataset.

# %%
# to check the Statistical summary-

baseball.describe()
# Out:
#              Wins        Runs      At_Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen_Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %% [markdown]
# #### KEY OBSERVATION FROM ABOVE STATISTICAL SUMMARY -
#
# - All the columns has same count as 30 which means that there is no null values in the dataset.
# - In Most of attributes, Mean and Median (50%) is approximatly same only some attributes such as 'At_Bats', 'Hits','Homeruns','Complete_game' and 'Errors' .Here , Mean value is greater than Median(50%) value which means that the data is right skewed .
# - Most of attributes data are normally distributed .Thereby,the chances of outliers are very less in our dataset.

# %% [markdown]
# ### CORRELATION MATRIX-

# %%
# Checking the Correlation Matrix-

plt.figure(figsize=(15,10))
plt.title('Correlation Map',fontsize = 18)
sns.heatmap(baseball.corr(),annot=True,cmap='YlOrRd_r');

# %% [markdown]
# #### KEY OBSERVATIONS -
# - Here 'Runs_Allowed','Earned Runs'and'Earned_Runes_Average_(AVG)' are highly negatively correlated with the target variable 'wins'.
# - Wherease,'Runs','Doubles','Save','Shutout','Homeruns' and 'Walks' are highly correlated to each other.

# %% [markdown]
# #### - CHECKING THE CORRELATION WITH THE TARGET VARIABLE 'Wins'.

# %%
baseball.corr()['Wins'].sort_values(ascending=False).drop(['Wins']).plot.bar(figsize=(10,8),color = 'm',grid=True,title='Correlation with Target',fontsize=15)
# Out:
# <AxesSubplot:title={'center':'Correlation with Target'}>

# %% [markdown]
# #### KEY OBSERVATIONS-
#
# - From the above observation , here 'Save','walk','Shutout','Runs','Doubles' and 'Homeruns' these are important features which are positivly correlated to our Target Attribute Wins.
# - 'Earned_Runs','Runs_Allowed'and'EarnedRun_Average(ERA)' these are the features which are highly negatively correlated to our target attribute.
# - Feature like 'Hits'and'At_Bats' has correlation value near to zero which means almost no significance for target attribute prediction'

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# #### Univariate Analysis -

# %%
def histplot(col):
    plt.figure(figsize=[5,4])
    sns.histplot(x =col,data = baseball,bins =6,kde=True)
    print(np.histogram(baseball[col],bins=6))

# %%
histplot('Wins')
# Out:
# (array([6, 3, 7, 6, 4, 4], dtype=int64), array([ 63.        ,  69.16666667,  75.33333333,  81.5       ,
#         87.66666667,  93.83333333, 100.        ]))

# %% [markdown]
# #### - Here most of the data in column 'Wins' is distributed between the count range 0-7 and 65-100.

# %%
histplot('Runs')
# Out:
# (array([ 3, 10, 12,  4,  0,  1], dtype=int64), array([573., 626., 679., 732., 785., 838., 891.]))

# %% [markdown]
# #### - Most of the data in column 'R'is distributed between the range 600 to 750.

# %%
histplot('At_Bats')
# Out:
# (array([4, 5, 7, 4, 6, 4], dtype=int64), array([5385., 5429., 5473., 5517., 5561., 5605., 5649.]))

# %% [markdown]
# ####  Most of the data in column 'At_Bats' is distributed between the range 5400-5650 with highest count at 5500.

# %%
histplot('Hits')
# Out:
# (array([ 6, 11,  4,  1,  3,  5], dtype=int64), array([1324.        , 1355.83333333, 1387.66666667, 1419.5       ,
#        1451.33333333, 1483.16666667, 1515.        ]))

# %% [markdown]
# #### - Most of the data in column 'Hits' is distributed between the range 1350-1375.

# %%
histplot('Doubles')
# Out:
# (array([ 3,  2,  5, 10,  7,  3], dtype=int64), array([236., 248., 260., 272., 284., 296., 308.]))

# %% [markdown]
# #### Most of the data in column 'Doubles' is distributed between the range 270-295.

# %%
histplot('Triples')
# Out:
# (array([4, 4, 7, 5, 5, 5], dtype=int64), array([13., 19., 25., 31., 37., 43., 49.]))

# %% [markdown]
# #### Most of the data in column 'Triples' is distributed between the range 25 to30.

# %%
histplot('Homeruns')
# Out:
# (array([2, 7, 7, 9, 1, 4], dtype=int64), array([100., 122., 144., 166., 188., 210., 232.]))

# %% [markdown]
# #### Most of the data in column 'Homeruns' is distributed bwetween the range 120 to 190.

# %%
histplot('Walks')
# Out:
# (array([5, 6, 4, 8, 2, 5], dtype=int64), array([375. , 407.5, 440. , 472.5, 505. , 537.5, 570. ]))

# %% [markdown]
# #### Most of the data in columns 'Walks' is distributed in range 475-500

# %%
histplot('Strikeouts')
# Out:
# (array([ 1,  6,  5, 15,  2,  1], dtype=int64), array([ 973.        , 1063.83333333, 1154.66666667, 1245.5       ,
#        1336.33333333, 1427.16666667, 1518.        ]))

# %% [markdown]
# #### Most of the data in column 'Strikeouts' is distributed between the range 1250 to 1330.

# %%
histplot('Runs_Allowed')
# Out:
# (array([ 1,  6,  7, 10,  3,  3], dtype=int64), array([525.        , 578.16666667, 631.33333333, 684.5       ,
#        737.66666667, 790.83333333, 844.        ]))

# %% [markdown]
# #### Most of the data in column 'Runallowed' is distributed between the range 600 to 740.

# %%
histplot('Earned_Runs')
# Out:
# (array([ 1,  7,  6, 10,  3,  3], dtype=int64), array([478. , 531.5, 585. , 638.5, 692. , 745.5, 799. ]))

# %% [markdown]
# ####  Most of the data in column 'Earnedruns' is distributed between the range 530 to 690.

# %%
histplot('EarnedRun_Average(ERA)')
# Out:
# (array([ 2,  5,  7, 12,  2,  2], dtype=int64), array([2.94, 3.29, 3.64, 3.99, 4.34, 4.69, 5.04]))

# %% [markdown]
# ####  most of the data in column 'ERA' is distributed between the range 3.99 - 4.35.

# %%
histplot('Complete_game')
# Out:
# (array([10,  7,  5,  7,  0,  1], dtype=int64), array([ 0.        ,  1.83333333,  3.66666667,  5.5       ,  7.33333333,
#         9.16666667, 11.        ]))

# %% [markdown]
# ####  most of the data in column 'CompleteGame' is distributed between the range 0-7.5.

# %%
histplot('Save')
# Out:
# (array([1, 9, 8, 8, 2, 2], dtype=int64), array([28.        , 33.66666667, 39.33333333, 45.        , 50.66666667,
#        56.33333333, 62.        ]))

# %% [markdown]
# #### most of the data in column 'Save' is distributed between the range 33 to 50.

# %%
histplot('Errors')
# Out:
# (array([ 5, 10,  8,  1,  3,  3], dtype=int64), array([ 75. ,  83.5,  92. , 100.5, 109. , 117.5, 126. ]))

# %% [markdown]
# #### Most of the data in column 'Errors' is distributed between the range 80 to 100.

# %% [markdown]
# ### BIVARIATE ANLAYSIS-

# %% [markdown]
# #### Analysing and Visualising various different features with Target variable 'Wins'

# %%
for i in baseball.columns:
    sns.regplot(x=i,y='Wins',data=baseball,color='crimson')
    plt.show()

# %% [markdown]
# #### KEY OBSERVATIONS -
#
# - From the above observations , we can see that Runs , doubles , homeruns , walks ,shutouts and save,are in linear relationship with the target variable 'Wins'.
# - Whereas,Run allowed, earned run and ERA is not in linear relationship with the target variable .Hence is negatively correlated as observed in correlation matrix.

# %% [markdown]
# ### Visualising the Dependent variables more in depth with other Featues using lineplot-

# %%
plt.figure(figsize=(12,6))
sns.set_style('darkgrid')
plt.title('Saves Vs Number of Wins ',fontsize=15)
sns.lineplot(x=baseball['Save'],y=baseball['Wins'],data=baseball)
plt.show()

# %% [markdown]
# #### - Although, there are few fluctuations but as the number of 'Save' increase , the chances of winning the Game also increases.

# %%
plt.figure(figsize=(12,6))

plt.title('Walk Vs Number of Wins ',fontsize=15)
sns.lineplot(x=baseball['Walks'],y=baseball['Wins'],data=baseball)
plt.show()

# %% [markdown]
# #### - As number of walks increases, the chances of winnings also increases, thereby showing linear relationship.

# %%
plt.figure(figsize=(12,6))

plt.title('Shutout Vs Number of Wins ',fontsize=15)
sns.lineplot(x=baseball['Shutout'],y=baseball['Wins'],data=baseball)
plt.show()

# %% [markdown]
# #### - As number of Shutout increases the chances of winnings the game also get increases.This shows linear relationship with the target variable 'Wins'.

# %%
plt.figure(figsize=(12,6))

plt.title('ERA Vs Number of Wins ',fontsize=15)
sns.lineplot(x=baseball['EarnedRun_Average(ERA)'],y=baseball['Wins'],data=baseball)
plt.show()

# %% [markdown]
# - The datapoints shows negative or declining slope which is suggestive of as the Earned_Runs_Average increases,the chances of winnings a game decreases.

# %%
plt.figure(figsize=(12,6))

plt.title('Earned Runs  Vs Number of Wins ',fontsize=15)
sns.lineplot(x=baseball['Earned_Runs'],y=baseball['Wins'],data=baseball)
plt.show()

# %% [markdown]
# #### - Here the datapoints shows a negative slope which means as the Earned Runs increases,the chances of winnings a game decreases.Thereby , this trend shows inverse relationship between Earned Runs and target variable 'Wins'.

# %%
plt.figure(figsize=(12,6))

plt.title('Runs Allowed Vs Number of Wins ',fontsize=15)
sns.lineplot(x=baseball['Runs_Allowed'],y=baseball['Wins'],data=baseball)
plt.show()

# %% [markdown]
# #### - Here as the Runs allowed increases we can see that the chances of wininigs are getting lesser,hence showing negative slope.Also , there are huge fluctuations in the datapoints.

# %%
sns.pairplot(data=baseball,palette='Dark2',kind = 'reg')

# %% [markdown]
# #### - This shows pairwise distribution or relation between the features.

# %% [markdown]
# ## DATA DISTRIBUTION-
# ### (Checking skewness )

# %%
plt.figure(figsize=(15,10))
plot=1
for col in baseball:
    if plot<=10:
        plt.subplot(4,3,plot)
        sns.distplot(baseball[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# #### KEY OBSERVATIONS-
#
# - All the data is normally distributed .Thereby lets further proceed to check the outliers in our dataset.

# %% [markdown]
# ## DETECTING OUTLIERS -

# %%
# plotting a box plot for each of the feature seperately to detect outliers :

for col in baseball:
    plt.figure(figsize=(16,4))
    sns.boxplot(baseball[col],color='slateblue')
    plt.show()

# %% [markdown]
# #### - There are outliers present in some features.

# %% [markdown]
# ## REMOVING OUTLIERS-

# %% [markdown]
# ### 1) IQR METHOD

# %%
# IQR METHOD - addressing outliers using the IOR:

Q1 = baseball.quantile(0.25)
Q3 = baseball.quantile(0.75)
IQR = Q3 - Q1

baseball_data = baseball[~((baseball < (Q1 - 1.5 * IQR)) |(baseball > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
plt.figure(figsize = [12,10])
for i in range(0,len(baseball_data.columns.values)):
    plt.subplot(2,9,i+1)
    sns.boxplot(y = baseball_data[baseball_data.columns.values[i]],color='orangered')
    plt.tight_layout()

# %%
print('percentage of loss of data by IQR is :',(baseball.shape[0]-baseball_data.shape[0])/baseball.shape[0])
# Out:
# percentage of loss of data by IQR is : 0.3333333333333333

# %%
len(baseball_data),len(baseball)
# Out:
# (20, 30)

# %% [markdown]
# ### 2) USING Z SCORE

# %%
#importing necessary Libaray-

from scipy.stats import zscore

z =np.abs(zscore(baseball))
print(z.shape)
bb = baseball.loc[(z<3).all(axis=1)]
print(bb.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
print('percentage of loss of data by Z-score is :',(baseball.shape[0]-bb.shape[0])/baseball.shape[0])
# Out:
# percentage of loss of data by Z-score is : 0.03333333333333333

# %% [markdown]
# #### KEY OBSERVATIONS-
# - While removing outliers from the data using IQR ,we are ending up removing 1/3 i.e. 0.333 percent of the data which is not acceptable .so we are proceeding with Z-score method of removing outliers ,as the percentage of data loss is comparitively less(0.03).
# - Outliers have been reduced to some extent.

# %% [markdown]
# ### HANDLING SKEWNESS -

# %%
# Checking the skewness in the dataset-

bb.skew()
# Out:
# Wins                      0.119013
# Runs                     -0.215364
# At_Bats                   0.169573
# Hits                      0.783772
# Doubles                  -0.335304
# Triples                   0.090124
# Homeruns                  0.450862
# Walks                     0.151193
# Strikeouts               -0.233815
# Stolen_Bases              0.494966
# Runs_Allowed              0.018155
# Earned_Runs               0.018461
# EarnedRun_Average(ERA)    0.016693
# Complete_game             0.854980
# Shutout                   0.526943
# Save                      0.627480
# Errors                    0.840271
# dtype: float64

# %% [markdown]
# ### DIVIDING THE VARIABLE INTO X AND Y VARIABLES -

# %%
# Split the features and the target variables into X and y respectively.

x=bb.drop(columns=['Wins'],axis=1)
y=bb['Wins']

# %%
# check the shapes of the variables-

x.shape,y.shape
# Out:
# ((29, 16), (29,))

# %%
#We are setting the standard limit for skewness as +/-0.5.

x.skew().sort_values(ascending=False)[np.abs(x.skew())>0.5]
# Out:
# Complete_game    0.854980
# Errors           0.840271
# Hits             0.783772
# Save             0.627480
# Shutout          0.526943
# dtype: float64

# %% [markdown]
# - These are the following columns which does not lie within the range of skewness,( +/-0.5).
# - As Skewness is present in these columns .Lets remove the skewness in these columns by transforming the data.

# %%
from sklearn.preprocessing import power_transform

def skewness(col):
    x[col]=power_transform((x[col].values.reshape(-1,1)),method='yeo-johnson')

# %%
skewness('Complete_game')
skewness('Errors')
skewness('Hits')
skewness('Save')
skewness('Shutout')

# %%
x.skew()
# Out:
# Runs                     -0.215364
# At_Bats                   0.169573
# Hits                      0.000000
# Doubles                  -0.335304
# Triples                   0.090124
# Homeruns                  0.450862
# Walks                     0.151193
# Strikeouts               -0.233815
# Stolen_Bases              0.494966
# Runs_Allowed              0.018155
# Earned_Runs               0.018461
# EarnedRun_Average(ERA)    0.016693
# Complete_game            -0.045947
# Shutout                   0.000529
# Save                     -0.000925
# Errors                    0.065585
# dtype: float64

# %% [markdown]
# - Skewness is reduced

# %%
#Rechecking the skewness to validate -

x.skew().sort_values(ascending=False)[np.abs(x.skew())>0.5]
# Out:
# Series([], dtype: float64)

# %%
# Plotting the data in boxplot

plt.figure(figsize=(22,15))
sns.boxplot(data=x, orient="h");

# %% [markdown]
# ## Checking  Multicolinearity .

# %%
x = bb.drop(['Wins'],axis = 1)
y = bb.Wins
z = x.columns

print(x.shape)
print(y.shape)
# Out:
# (29, 16)
# (29,)

# %% [markdown]
# ### APPLYING SCALING METHOD TO THE DATA

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x = sc.fit_transform(x)
x = pd.DataFrame(x,columns = z)
x
# Out:
#         Runs   At_Bats      Hits   Doubles   Triples  Homeruns     Walks  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %% [markdown]
# ### - Using User defined function to calculate Variance inflation Factor.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vifscore(x):
    vif = pd.DataFrame()
    vif['Column Name'] = x.columns
    vif['VIF Factor'] = [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif.sort_values('VIF Factor',ascending = False))

# %%
vifscore(x)
# Out:
#                Column Name   VIF Factor
# 10             Earned_Runs  1825.871631
# 11  EarnedRun_Average(ERA)  1438.816208
# 9             Runs_Allowed   197.315706
# 1                  At_Bats    18.333377
# 2                     Hits    10.558458
# 5                 Homeruns     8.426403
# 0                     Runs     7.229564
# 14                    Save     6.236487
# 3                  Doubles     3.743423
# 13                 Shutout     3.673885
# 6                    Walks     3.431971
# 4                  Triples     3.278636
# 12           Complete_game     3.074115
# 7               Strikeouts     2.720640
# 15                  Errors     2.180914
# 8             Stolen_Bases     2.110804

# %% [markdown]
# - There is Multicolinearity is present in columns . Let's first try dropping few columns with variance inflation and calculate the VIF again.

# %%
base = x.copy()
base.drop(['EarnedRun_Average(ERA)','Runs_Allowed'],axis = 1, inplace = True)
base
# Out:
#         Runs   At_Bats      Hits   Doubles   Triples  Homeruns     Walks  \
# 0   0.959398  0.830084  1.738306  1.556538  1.010845 -0.765863 -1.536359
# 1   0.331147 -0.702831 -0.938698  0.201171  1.208917 -0.181389 -0.495021
# 2  -0.274666 -1.100253 -0.106656  1.733325 -0.276617 -0.697101  1.252941
# 3  -1.329231  0.233951 -0.359886 -0.800621 -0.474688 -0.869006 -1.145857
# 4   0.174084  1.255894  2.063888  0.908319  1.704094 -0.353293 -0.197495
# 5   1.856900  0.716535 -0.070480 -0.093474 -1.266972  1.743939  1.643442
# 6   0.712585 -0.447345 -0.558853 -1.625627 -1.167936  1.915843 -0.885522
# 7  -0.835605 -0.447345 -0.323710  0.260100  0.020490  0.196801 -0.550807
# 8   1.497899  1.752672  1.702131  1.202964  0.119526 -0.009484  0.230197
# 9   1.565212 -0.078310  0.327453  0.319029  0.020490  0.368705  0.695081
# 10  1.071586 -0.816380 -0.685468  0.260100 -0.573723  2.362794  0.378960
# 11 -0.454167 -1.412514 -1.264279 -1.802414 -1.068901  0.506228 -0.569402
# ...

# %%
vifscore(base)
# Out:
#       Column Name  VIF Factor
# 2            Hits    8.404938
# 0            Runs    6.835604
# 5        Homeruns    6.605412
# 1         At_Bats    4.947348
# 9     Earned_Runs    4.835616
# 3         Doubles    3.442889
# 4         Triples    3.237345
# 11        Shutout    3.211984
# 6           Walks    3.090022
# 12           Save    2.933661
# 10  Complete_game    2.650379
# 7      Strikeouts    2.107946
# 13         Errors    2.034087
# 8    Stolen_Bases    1.827627

# %% [markdown]
# #### After dropping the columns 'EarnedRun_Average(ERA)' and 'Runs_Allowed' the variance inflation factor is reduced , So our model is now not having much multicolinearity.

# %% [markdown]
# ## MODEL BUIDING

# %% [markdown]
# ### Splitting the data into input and output

# %%
input = base.copy()
output = y.copy()

# %%
print(input.shape)
print(output.shape)
# Out:
# (29, 14)
# (29,)

# %%
 Models:
from s#klearn.model_selection import train_test_split


from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn import metrics

# for cross validation
from sklearn.model_selection import cross_val_score,GridSearchCV  

#Matrics for Evaluation
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score

# %%
lr  = LinearRegression()
rf  = RandomForestRegressor()
dt  = DecisionTreeRegressor()
knn = KNeighborsRegressor()
gbr = GradientBoostingRegressor()
ada = AdaBoostRegressor()

# %% [markdown]
# #### Finding the best random state

# %%
#User defined function for finding the best random state
def best_ran(model):
    maxacc = 0
    maxrs = 0
    print(model)
    for i in range(1,100):
        x_train, x_test,y_train,y_test= train_test_split(input,output,test_size = 0.20, random_state = i)
        model.fit(x_train,y_train)
        pred_test = model.predict(x_test)
        acc = r2_score(y_test,pred_test)
        if acc>maxacc:
            maxacc = acc
            maxrs = i
    print("At random state ", maxrs, 'the model is having r2 score of ', maxacc)

# %%
def mod_test(model, ran):
    x_train, x_test,y_train,y_test= train_test_split(input,output,test_size = 0.20, random_state = ran)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    acc = r2_score(y_test,pred_test)
    mse = mean_squared_error(y_test,pred_test)
    mae = mean_absolute_error(y_test,pred_test)
    print("R2 score is ", acc)
    print("_"*50)
    print("Mean Sqaured Error is ",mse)
    print("_"*50)
    print("Mean Absolute Error is ",mae)
    print("_"*50)

# %% [markdown]
# ## LinearRegression

# %%
best_ran(lr)
# Out:
# LinearRegression()
# At random state  47 the model is having r2 score of  0.978613842099432

# %%
mod_test(lr,47)
print("Coefficent is ",lr.coef_)
print("_"*50)
print("Intercept is ",lr.intercept_)
print("_"*50)
# Out:
# R2 score is  0.978613842099432
# __________________________________________________
# Mean Sqaured Error is  2.6994083750050173
# __________________________________________________
# Mean Absolute Error is  1.387173555709963
# __________________________________________________
# Coefficent is  [ 6.84747674  0.80101305 -1.13673448 -2.05976449 -0.65311447 -2.99581144
#  -1.43695723  0.73143266 -0.32097441 -4.43571994  2.66957731  1.46715687
#   5.69154696 -0.25041358]
# __________________________________________________
# Intercept is  80.36981793138229
# __________________________________________________

# %% [markdown]
# ## KNeighborsRegressor

# %%
best_ran(knn)
# Out:
# KNeighborsRegressor()
# At random state  61 the model is having r2 score of  0.7670606293169608

# %%
mod_test(knn,61)
# Out:
# R2 score is  0.7670606293169608
# __________________________________________________
# Mean Sqaured Error is  25.29333333333334
# __________________________________________________
# Mean Absolute Error is  3.7333333333333343
# __________________________________________________

# %% [markdown]
# ## DecisionTreeRegressor

# %%
best_ran(dt)
# Out:
# DecisionTreeRegressor()
# At random state  1 the model is having r2 score of  0.8305489260143198

# %%
mod_test(dt,1)
# Out:
# R2 score is  0.8544152744630071
# __________________________________________________
# Mean Sqaured Error is  20.333333333333332
# __________________________________________________
# Mean Absolute Error is  4.0
# __________________________________________________

# %% [markdown]
# ## RandomForestRegressor

# %%
best_ran(rf)
# Out:
# RandomForestRegressor()
# At random state  5 the model is having r2 score of  0.7800852611218564

# %%
mod_test(rf,5)
# Out:
# R2 score is  0.752577408123791
# __________________________________________________
# Mean Sqaured Error is  17.766316666666672
# __________________________________________________
# Mean Absolute Error is  3.761666666666668
# __________________________________________________

# %% [markdown]
# ## AdaBoostRegressor

# %%
best_ran(ada)
# Out:
# AdaBoostRegressor()
# At random state  75 the model is having r2 score of  0.8553665543755473

# %%
mod_test(ada,75)
# Out:
# R2 score is  0.8516615279205206
# __________________________________________________
# Mean Sqaured Error is  20.0462962962963
# __________________________________________________
# Mean Absolute Error is  3.611111111111112
# __________________________________________________

# %% [markdown]
# ## GradientBoostingRegressor

# %%
best_ran(gbr)
# Out:
# GradientBoostingRegressor()
# At random state  4 the model is having r2 score of  0.9085807918103324

# %%
mod_test(gbr,4)
# Out:
# R2 score is  0.8879491442497087
# __________________________________________________
# Mean Sqaured Error is  9.913388210129941
# __________________________________________________
# Mean Absolute Error is  2.6251262331243126
# __________________________________________________

# %% [markdown]
# #### From the above algorithms, the linear regression is providing the maximum R2 Score of 97.86%. Now let's cross validate the models to check whether they are performing well with cross validation or not.

# %% [markdown]
# ## CROSS VALIDATION

# %%
#User defined function for checking cross validation for each model


def cross_val(model,ran):    #ran = random_state
    cv_mean = 0
    cv_fold = 0
    x_train, x_test, y_train, y_test = train_test_split(input,output,test_size = 0.20, random_state = ran)
    model.fit(x_train,y_train)
    pred_test = model.predict(x_test)
    for j in range(2,10):
        cv_score = cross_val_score(model,input,output, cv = j)
        a =cv_score.mean()
        if a>cv_mean:
            cv_mean = a
            cv_fold = j
    print(model)
    print("At cv fold",cv_fold," the cv score is ", cv_mean, "and the R2 score  is ",r2_score(y_test,pred_test))

# %%
cross_val(lr,47)
# Out:
# LinearRegression()
# At cv fold 8  the cv score is  0.3172035869246073 and the R2 score  is  0.978613842099432

# %%
cross_val(knn,61)
# Out:
# KNeighborsRegressor()
# At cv fold 4  the cv score is  0.4923013454829934 and the R2 score  is  0.7670606293169608

# %%
cross_val(dt,1)
# Out:
# DecisionTreeRegressor()
# At cv fold 0  the cv score is  0 and the R2 score  is  0.6992840095465394

# %%
cross_val(rf,5)
# Out:
# RandomForestRegressor()
# At cv fold 4  the cv score is  0.4738807750917928 and the R2 score  is  0.7390350483558993

# %%
cross_val(ada,75)
# Out:
# AdaBoostRegressor()
# At cv fold 4  the cv score is  0.4918992370151042 and the R2 score  is  0.7593881919257981

# %%
cross_val(gbr,4)
# Out:
# GradientBoostingRegressor()
# At cv fold 4  the cv score is  0.3689434400212823 and the R2 score  is  0.8814969245472168

# %% [markdown]
# ### The model Linear Regression(lr) after cross validation is providing R2 score of 97.86% .
# #### The Linear Regression model(lr) is giving the maximum R2 score and Cross validation mean score after cross validation. So we can choose the Linear Regression model as the best model.

# %% [markdown]
# ## HYPERPARAMETER TUNNING OF LINEAR REGRESSION

# %%
parameters = {'fit_intercept':[True, False],
             'normalize':[True, False],
             'copy_X' : [True, False],
             'n_jobs':list(range(1,10)),
             'positive':[True, False]}
grid = GridSearchCV(estimator=LinearRegression(),param_grid=parameters,cv = 8)

# %%
grid.fit(input,output)
grid.best_score_
# Out:
# 0.3172035869246088

# %%
grid.best_params_
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': 1,
#  'normalize': True,
#  'positive': False}

# %%
lr = LinearRegression(copy_X = True, fit_intercept = True,n_jobs = 1,normalize =True,positive=False)
x_train,x_test,y_train,y_test = train_test_split(input,output,test_size=0.2,random_state=47)
lr.fit(x_train, y_train)
pred_test = lr.predict(x_test)

print('R2 Score',r2_score(y_test,pred_test))
print('Mean Squared Error',mean_squared_error(y_test,pred_test))
print('Mean Absolute Error',mean_absolute_error(y_test,pred_test))
# Out:
# R2 Score 0.978613842099432
# Mean Squared Error 2.699408375005028
# Mean Absolute Error 1.3871735557099665

# %% [markdown]
# #### Our model is performing the same after the tuning.

# %% [markdown]
# ## After all the tests and cross validation, our model (LINEAR REGRESSION) is performing well compared to other algorithms and giving an R2 score of 97.86% with a mean squared error of 2.6, mean absolute error of 1.3.

# %% [markdown]
# ## SAVING THE MODEL

# %%
import pickle

filename = 'Baseball_Case_study_prediction.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# ## CONCLUSION-

# %%
Actual = np.array(y_test)
predicted = np.round(np.array(lr.predict(x_test)),2)

predicted = pd.DataFrame({'Original Value (W)':Actual,'Predicted Value (W)':predicted})
predicted
# Out:
#    Original Value (W)  Predicted Value (W)
# 0                 100                97.37
# 1                  76                75.71
# 2                  74                73.72
# 3                  86                83.80
# 4                  76                77.52
# 5                  64                62.61

# %% [markdown]
# #### Our model is performing perfectly with the predictions.

# %% [markdown]
# #### (***********************************COMPLETED************************************)
